# %%
from fastai import *
from fastai.vision.all import *
path = untar_data(URLs.MNIST_SAMPLE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from fastai import *
# ----> 2 from fastai.vision.all import *
#       3 path = untar_data(URLs.MNIST_SAMPLE)
#
# File D:\conda\envs\py39\lib\site-packages\fastai\vision\all.py:1
# ----> 1 from . import models
#       2 from ..basics import *
#       3 from ..callback.all import *
#
# File D:\conda\envs\py39\lib\site-packages\fastai\vision\models\__init__.py:1
# ----> 1 from . import xresnet
#       2 from . import unet
#       3 from .tvm import *
#
# File D:\conda\envs\py39\lib\site-packages\fastai\vision\models\xresnet.py:7
#       3 # AUTOGENERATED! DO NOT EDIT! File to edit: ../../../nbs/11_vision.models.xresnet.ipynb.
#       4
#       5 # %% ../../../nbs/11_vision.models.xresnet.ipynb 2
#       6 from __future__ import annotations
# ----> 7 from ...torch_basics import *
# ...
